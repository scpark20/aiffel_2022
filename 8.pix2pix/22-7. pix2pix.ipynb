# %%
# !mkdir data
# !wget -O data/sketch2pokemon.zip https://d3s0tskafalll9.cloudfront.net/media/documents/sketch2pokemon.zip
# !cd data && unzip sketch2pokemon.zip
# Out:
# --2022-09-30 03:42:15--  https://d3s0tskafalll9.cloudfront.net/media/documents/sketch2pokemon.zip
# Resolving d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)... 18.172.167.54, 18.172.167.190, 18.172.167.92, ...
# Connecting to d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)|18.172.167.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66732281 (64M) [application/zip]
# Saving to: ‘data/sketch2pokemon.zip’
#
# data/sketch2pokemon 100%[===================>]  63.64M  21.3MB/s    in 3.0s
#
# 2022-09-30 03:42:19 (21.3 MB/s) - ‘data/sketch2pokemon.zip’ saved [66732281/66732281]
#
# Archive:  sketch2pokemon.zip
#    creating: pokemon_pix2pix_dataset/
#    creating: pokemon_pix2pix_dataset/train/
#   inflating: pokemon_pix2pix_dataset/train/0.jpg
#   inflating: pokemon_pix2pix_dataset/train/1.jpg
#   inflating: pokemon_pix2pix_dataset/train/10.jpg
#   inflating: pokemon_pix2pix_dataset/train/100.jpg
#   inflating: pokemon_pix2pix_dataset/train/101.jpg
#   inflating: pokemon_pix2pix_dataset/train/102.jpg
#   inflating: pokemon_pix2pix_dataset/train/103.jpg
#   inflating: pokemon_pix2pix_dataset/train/104.jpg
#   inflating: pokemon_pix2pix_dataset/train/105.jpg
#   inflating: pokemon_pix2pix_dataset/train/106.jpg
#   inflating: pokemon_pix2pix_dataset/train/107.jpg
#   inflating: pokemon_pix2pix_dataset/train/108.jpg
#   inflating: pokemon_pix2pix_dataset/train/109.jpg
#   inflating: pokemon_pix2pix_dataset/train/11.jpg
#   inflating: pokemon_pix2pix_dataset/train/110.jpg
#   inflating: pokemon_pix2pix_dataset/train/111.jpg
#   inflating: pokemon_pix2pix_dataset/train/112.jpg
#   inflating: pokemon_pix2pix_dataset/train/113.jpg
#   inflating: pokemon_pix2pix_dataset/train/114.jpg
#   inflating: pokemon_pix2pix_dataset/train/115.jpg
#   inflating: pokemon_pix2pix_dataset/train/116.jpg
#   inflating: pokemon_pix2pix_dataset/train/117.jpg
#   inflating: pokemon_pix2pix_dataset/train/118.jpg
#   inflating: pokemon_pix2pix_dataset/train/119.jpg
#   inflating: pokemon_pix2pix_dataset/train/12.jpg
#   inflating: pokemon_pix2pix_dataset/train/120.jpg
#   inflating: pokemon_pix2pix_dataset/train/121.jpg
#   inflating: pokemon_pix2pix_dataset/train/122.jpg
#   inflating: pokemon_pix2pix_dataset/train/123.jpg
#   inflating: pokemon_pix2pix_dataset/train/124.jpg
#   inflating: pokemon_pix2pix_dataset/train/125.jpg
#   inflating: pokemon_pix2pix_dataset/train/126.jpg
#   inflating: pokemon_pix2pix_dataset/train/127.jpg
#   inflating: pokemon_pix2pix_dataset/train/128.jpg
#   inflating: pokemon_pix2pix_dataset/train/129.jpg
#   inflating: pokemon_pix2pix_dataset/train/13.jpg
#   inflating: pokemon_pix2pix_dataset/train/178.jpg
#   inflating: pokemon_pix2pix_dataset/train/179.jpg
#   inflating: pokemon_pix2pix_dataset/train/18.jpg
#   inflating: pokemon_pix2pix_dataset/train/180.jpg
#   inflating: pokemon_pix2pix_dataset/train/181.jpg
#   inflating: pokemon_pix2pix_dataset/train/182.jpg
#   inflating: pokemon_pix2pix_dataset/train/183.jpg
#   inflating: pokemon_pix2pix_dataset/train/184.jpg
#   inflating: pokemon_pix2pix_dataset/train/185.jpg
#   inflating: pokemon_pix2pix_dataset/train/186.jpg
#   inflating: pokemon_pix2pix_dataset/train/187.jpg
#   inflating: pokemon_pix2pix_dataset/train/188.jpg
#   inflating: pokemon_pix2pix_dataset/train/189.jpg
#   inflating: pokemon_pix2pix_dataset/train/19.jpg
#   inflating: pokemon_pix2pix_dataset/train/190.jpg
#   inflating: pokemon_pix2pix_dataset/train/191.jpg
#   inflating: pokemon_pix2pix_dataset/train/192.jpg
#   inflating: pokemon_pix2pix_dataset/train/193.jpg
#   inflating: pokemon_pix2pix_dataset/train/194.jpg
#   inflating: pokemon_pix2pix_dataset/train/195.jpg
#   inflating: pokemon_pix2pix_dataset/train/196.jpg
#   inflating: pokemon_pix2pix_dataset/train/197.jpg
#   inflating: pokemon_pix2pix_dataset/train/198.jpg
#   inflating: pokemon_pix2pix_dataset/train/199.jpg
#   inflating: pokemon_pix2pix_dataset/train/2.jpg
#   inflating: pokemon_pix2pix_dataset/train/20.jpg
#   inflating: pokemon_pix2pix_dataset/train/200.jpg
#   inflating: pokemon_pix2pix_dataset/train/201.jpg
#   inflating: pokemon_pix2pix_dataset/train/202.jpg
#   inflating: pokemon_pix2pix_dataset/train/203.jpg
#   inflating: pokemon_pix2pix_dataset/train/204.jpg
#   inflating: pokemon_pix2pix_dataset/train/205.jpg
#   inflating: pokemon_pix2pix_dataset/train/206.jpg
#   inflating: pokemon_pix2pix_dataset/train/207.jpg
#   inflating: pokemon_pix2pix_dataset/train/208.jpg
#   inflating: pokemon_pix2pix_dataset/train/209.jpg
#   inflating: pokemon_pix2pix_dataset/train/21.jpg
#   inflating: pokemon_pix2pix_dataset/train/210.jpg
#   inflating: pokemon_pix2pix_dataset/train/211.jpg
#   inflating: pokemon_pix2pix_dataset/train/212.jpg
#   inflating: pokemon_pix2pix_dataset/train/213.jpg
#   inflating: pokemon_pix2pix_dataset/train/214.jpg
#   inflating: pokemon_pix2pix_dataset/train/215.jpg
#   inflating: pokemon_pix2pix_dataset/train/216.jpg
#   inflating: pokemon_pix2pix_dataset/train/217.jpg
#   inflating: pokemon_pix2pix_dataset/train/218.jpg
#   inflating: pokemon_pix2pix_dataset/train/219.jpg
#   inflating: pokemon_pix2pix_dataset/train/22.jpg
#   inflating: pokemon_pix2pix_dataset/train/220.jpg
#   inflating: pokemon_pix2pix_dataset/train/221.jpg
#   inflating: pokemon_pix2pix_dataset/train/222.jpg
#   inflating: pokemon_pix2pix_dataset/train/223.jpg
#   inflating: pokemon_pix2pix_dataset/train/272.jpg
#   inflating: pokemon_pix2pix_dataset/train/273.jpg
#   inflating: pokemon_pix2pix_dataset/train/274.jpg
#   inflating: pokemon_pix2pix_dataset/train/275.jpg
#   inflating: pokemon_pix2pix_dataset/train/276.jpg
#   inflating: pokemon_pix2pix_dataset/train/277.jpg
#   inflating: pokemon_pix2pix_dataset/train/278.jpg
#   inflating: pokemon_pix2pix_dataset/train/279.jpg
#   inflating: pokemon_pix2pix_dataset/train/28.jpg
#   inflating: pokemon_pix2pix_dataset/train/280.jpg
#   inflating: pokemon_pix2pix_dataset/train/281.jpg
#   inflating: pokemon_pix2pix_dataset/train/282.jpg
#   inflating: pokemon_pix2pix_dataset/train/283.jpg
#   inflating: pokemon_pix2pix_dataset/train/284.jpg
#   inflating: pokemon_pix2pix_dataset/train/285.jpg
#   inflating: pokemon_pix2pix_dataset/train/286.jpg
#   inflating: pokemon_pix2pix_dataset/train/287.jpg
#   inflating: pokemon_pix2pix_dataset/train/288.jpg
#   inflating: pokemon_pix2pix_dataset/train/289.jpg
#   inflating: pokemon_pix2pix_dataset/train/29.jpg
#   inflating: pokemon_pix2pix_dataset/train/290.jpg
#   inflating: pokemon_pix2pix_dataset/train/291.jpg
#   inflating: pokemon_pix2pix_dataset/train/292.jpg
#   inflating: pokemon_pix2pix_dataset/train/293.jpg
#   inflating: pokemon_pix2pix_dataset/train/294.jpg
#   inflating: pokemon_pix2pix_dataset/train/295.jpg
#   inflating: pokemon_pix2pix_dataset/train/296.jpg
#   inflating: pokemon_pix2pix_dataset/train/297.jpg
#   inflating: pokemon_pix2pix_dataset/train/298.jpg
#   inflating: pokemon_pix2pix_dataset/train/299.jpg
#   inflating: pokemon_pix2pix_dataset/train/3.jpg
#   inflating: pokemon_pix2pix_dataset/train/30.jpg
#   inflating: pokemon_pix2pix_dataset/train/300.jpg
#   inflating: pokemon_pix2pix_dataset/train/301.jpg
#   inflating: pokemon_pix2pix_dataset/train/302.jpg
#   inflating: pokemon_pix2pix_dataset/train/303.jpg
#   inflating: pokemon_pix2pix_dataset/train/304.jpg
#   inflating: pokemon_pix2pix_dataset/train/305.jpg
#   inflating: pokemon_pix2pix_dataset/train/306.jpg
#   inflating: pokemon_pix2pix_dataset/train/307.jpg
#   inflating: pokemon_pix2pix_dataset/train/308.jpg
#   inflating: pokemon_pix2pix_dataset/train/309.jpg
#   inflating: pokemon_pix2pix_dataset/train/31.jpg
#   inflating: pokemon_pix2pix_dataset/train/310.jpg
#   inflating: pokemon_pix2pix_dataset/train/311.jpg
#   inflating: pokemon_pix2pix_dataset/train/312.jpg
#   inflating: pokemon_pix2pix_dataset/train/313.jpg
#   inflating: pokemon_pix2pix_dataset/train/314.jpg
#   inflating: pokemon_pix2pix_dataset/train/315.jpg
#   inflating: pokemon_pix2pix_dataset/train/316.jpg
#   inflating: pokemon_pix2pix_dataset/train/317.jpg
#   inflating: pokemon_pix2pix_dataset/train/318.jpg
#   inflating: pokemon_pix2pix_dataset/train/366.jpg
#   inflating: pokemon_pix2pix_dataset/train/367.jpg
#   inflating: pokemon_pix2pix_dataset/train/368.jpg
#   inflating: pokemon_pix2pix_dataset/train/369.jpg
#   inflating: pokemon_pix2pix_dataset/train/37.jpg
#   inflating: pokemon_pix2pix_dataset/train/370.jpg
#   inflating: pokemon_pix2pix_dataset/train/371.jpg
#   inflating: pokemon_pix2pix_dataset/train/372.jpg
#   inflating: pokemon_pix2pix_dataset/train/373.jpg
#   inflating: pokemon_pix2pix_dataset/train/374.jpg
#   inflating: pokemon_pix2pix_dataset/train/375.jpg
#   inflating: pokemon_pix2pix_dataset/train/376.jpg
#   inflating: pokemon_pix2pix_dataset/train/377.jpg
#   inflating: pokemon_pix2pix_dataset/train/378.jpg
#   inflating: pokemon_pix2pix_dataset/train/379.jpg
#   inflating: pokemon_pix2pix_dataset/train/38.jpg
#   inflating: pokemon_pix2pix_dataset/train/380.jpg
#   inflating: pokemon_pix2pix_dataset/train/381.jpg
#   inflating: pokemon_pix2pix_dataset/train/382.jpg
#   inflating: pokemon_pix2pix_dataset/train/383.jpg
#   inflating: pokemon_pix2pix_dataset/train/384.jpg
#   inflating: pokemon_pix2pix_dataset/train/385.jpg
#   inflating: pokemon_pix2pix_dataset/train/386.jpg
#   inflating: pokemon_pix2pix_dataset/train/387.jpg
#   inflating: pokemon_pix2pix_dataset/train/388.jpg
#   inflating: pokemon_pix2pix_dataset/train/389.jpg
#   inflating: pokemon_pix2pix_dataset/train/39.jpg
#   inflating: pokemon_pix2pix_dataset/train/390.jpg
#   inflating: pokemon_pix2pix_dataset/train/391.jpg
#   inflating: pokemon_pix2pix_dataset/train/392.jpg
#   inflating: pokemon_pix2pix_dataset/train/393.jpg
#   inflating: pokemon_pix2pix_dataset/train/394.jpg
#   inflating: pokemon_pix2pix_dataset/train/395.jpg
#   inflating: pokemon_pix2pix_dataset/train/396.jpg
#   inflating: pokemon_pix2pix_dataset/train/397.jpg
#   inflating: pokemon_pix2pix_dataset/train/398.jpg
#   inflating: pokemon_pix2pix_dataset/train/399.jpg
#   inflating: pokemon_pix2pix_dataset/train/4.jpg
#   inflating: pokemon_pix2pix_dataset/train/40.jpg
#   inflating: pokemon_pix2pix_dataset/train/400.jpg
#   inflating: pokemon_pix2pix_dataset/train/401.jpg
#   inflating: pokemon_pix2pix_dataset/train/402.jpg
#   inflating: pokemon_pix2pix_dataset/train/403.jpg
#   inflating: pokemon_pix2pix_dataset/train/404.jpg
#   inflating: pokemon_pix2pix_dataset/train/405.jpg
#   inflating: pokemon_pix2pix_dataset/train/406.jpg
#   inflating: pokemon_pix2pix_dataset/train/407.jpg
#   inflating: pokemon_pix2pix_dataset/train/408.jpg
#   inflating: pokemon_pix2pix_dataset/train/409.jpg
#   inflating: pokemon_pix2pix_dataset/train/41.jpg
#   inflating: pokemon_pix2pix_dataset/train/410.jpg
#   inflating: pokemon_pix2pix_dataset/train/411.jpg
#   inflating: pokemon_pix2pix_dataset/train/412.jpg
#   inflating: pokemon_pix2pix_dataset/train/460.jpg
#   inflating: pokemon_pix2pix_dataset/train/461.jpg
#   inflating: pokemon_pix2pix_dataset/train/462.jpg
#   inflating: pokemon_pix2pix_dataset/train/463.jpg
#   inflating: pokemon_pix2pix_dataset/train/464.jpg
#   inflating: pokemon_pix2pix_dataset/train/465.jpg
#   inflating: pokemon_pix2pix_dataset/train/466.jpg
#   inflating: pokemon_pix2pix_dataset/train/467.jpg
#   inflating: pokemon_pix2pix_dataset/train/468.jpg
#   inflating: pokemon_pix2pix_dataset/train/469.jpg
#   inflating: pokemon_pix2pix_dataset/train/47.jpg
#   inflating: pokemon_pix2pix_dataset/train/470.jpg
#   inflating: pokemon_pix2pix_dataset/train/471.jpg
#   inflating: pokemon_pix2pix_dataset/train/472.jpg
#   inflating: pokemon_pix2pix_dataset/train/473.jpg
#   inflating: pokemon_pix2pix_dataset/train/474.jpg
#   inflating: pokemon_pix2pix_dataset/train/475.jpg
#   inflating: pokemon_pix2pix_dataset/train/476.jpg
#   inflating: pokemon_pix2pix_dataset/train/477.jpg
#   inflating: pokemon_pix2pix_dataset/train/478.jpg
#   inflating: pokemon_pix2pix_dataset/train/479.jpg
#   inflating: pokemon_pix2pix_dataset/train/48.jpg
#   inflating: pokemon_pix2pix_dataset/train/480.jpg
#   inflating: pokemon_pix2pix_dataset/train/481.jpg
#   inflating: pokemon_pix2pix_dataset/train/482.jpg
#   inflating: pokemon_pix2pix_dataset/train/483.jpg
#   inflating: pokemon_pix2pix_dataset/train/484.jpg
#   inflating: pokemon_pix2pix_dataset/train/485.jpg
#   inflating: pokemon_pix2pix_dataset/train/486.jpg
#   inflating: pokemon_pix2pix_dataset/train/487.jpg
#   inflating: pokemon_pix2pix_dataset/train/488.jpg
#   inflating: pokemon_pix2pix_dataset/train/489.jpg
#   inflating: pokemon_pix2pix_dataset/train/49.jpg
#   inflating: pokemon_pix2pix_dataset/train/490.jpg
#   inflating: pokemon_pix2pix_dataset/train/491.jpg
#   inflating: pokemon_pix2pix_dataset/train/492.jpg
#   inflating: pokemon_pix2pix_dataset/train/493.jpg
#   inflating: pokemon_pix2pix_dataset/train/494.jpg
#   inflating: pokemon_pix2pix_dataset/train/495.jpg
#   inflating: pokemon_pix2pix_dataset/train/496.jpg
#   inflating: pokemon_pix2pix_dataset/train/497.jpg
#   inflating: pokemon_pix2pix_dataset/train/498.jpg
#   inflating: pokemon_pix2pix_dataset/train/499.jpg
#   inflating: pokemon_pix2pix_dataset/train/5.jpg
#   inflating: pokemon_pix2pix_dataset/train/50.jpg
#   inflating: pokemon_pix2pix_dataset/train/500.jpg
#   inflating: pokemon_pix2pix_dataset/train/501.jpg
#   inflating: pokemon_pix2pix_dataset/train/502.jpg
#   inflating: pokemon_pix2pix_dataset/train/503.jpg
#   inflating: pokemon_pix2pix_dataset/train/504.jpg
#   inflating: pokemon_pix2pix_dataset/train/505.jpg
#   inflating: pokemon_pix2pix_dataset/train/506.jpg
#   inflating: pokemon_pix2pix_dataset/train/507.jpg
#   inflating: pokemon_pix2pix_dataset/train/508.jpg
#   inflating: pokemon_pix2pix_dataset/train/509.jpg
#   inflating: pokemon_pix2pix_dataset/train/51.jpg
#   inflating: pokemon_pix2pix_dataset/train/510.jpg
#   inflating: pokemon_pix2pix_dataset/train/511.jpg
#   inflating: pokemon_pix2pix_dataset/train/512.jpg
#   inflating: pokemon_pix2pix_dataset/train/513.jpg
#   inflating: pokemon_pix2pix_dataset/train/514.jpg
#   inflating: pokemon_pix2pix_dataset/train/515.jpg
#   inflating: pokemon_pix2pix_dataset/train/516.jpg
#   inflating: pokemon_pix2pix_dataset/train/517.jpg
#   inflating: pokemon_pix2pix_dataset/train/518.jpg
#   inflating: pokemon_pix2pix_dataset/train/519.jpg
#   inflating: pokemon_pix2pix_dataset/train/52.jpg
#   inflating: pokemon_pix2pix_dataset/train/520.jpg
#   inflating: pokemon_pix2pix_dataset/train/521.jpg
#   inflating: pokemon_pix2pix_dataset/train/522.jpg
#   inflating: pokemon_pix2pix_dataset/train/523.jpg
#   inflating: pokemon_pix2pix_dataset/train/524.jpg
#   inflating: pokemon_pix2pix_dataset/train/525.jpg
#   inflating: pokemon_pix2pix_dataset/train/526.jpg
#   inflating: pokemon_pix2pix_dataset/train/527.jpg
#   inflating: pokemon_pix2pix_dataset/train/528.jpg
#   inflating: pokemon_pix2pix_dataset/train/529.jpg
#   inflating: pokemon_pix2pix_dataset/train/53.jpg
#   inflating: pokemon_pix2pix_dataset/train/530.jpg
#   inflating: pokemon_pix2pix_dataset/train/531.jpg
#   inflating: pokemon_pix2pix_dataset/train/532.jpg
#   inflating: pokemon_pix2pix_dataset/train/533.jpg
#   inflating: pokemon_pix2pix_dataset/train/534.jpg
#   inflating: pokemon_pix2pix_dataset/train/535.jpg
#   inflating: pokemon_pix2pix_dataset/train/536.jpg
#   inflating: pokemon_pix2pix_dataset/train/537.jpg
#   inflating: pokemon_pix2pix_dataset/train/538.jpg
#   inflating: pokemon_pix2pix_dataset/train/539.jpg
#   inflating: pokemon_pix2pix_dataset/train/54.jpg
#   inflating: pokemon_pix2pix_dataset/train/540.jpg
#   inflating: pokemon_pix2pix_dataset/train/541.jpg
#   inflating: pokemon_pix2pix_dataset/train/542.jpg
#   inflating: pokemon_pix2pix_dataset/train/543.jpg
#   inflating: pokemon_pix2pix_dataset/train/544.jpg
#   inflating: pokemon_pix2pix_dataset/train/545.jpg
#   inflating: pokemon_pix2pix_dataset/train/546.jpg
#   inflating: pokemon_pix2pix_dataset/train/547.jpg
#   inflating: pokemon_pix2pix_dataset/train/548.jpg
#   inflating: pokemon_pix2pix_dataset/train/549.jpg
#   inflating: pokemon_pix2pix_dataset/train/55.jpg
#   inflating: pokemon_pix2pix_dataset/train/550.jpg
#   inflating: pokemon_pix2pix_dataset/train/551.jpg
#   inflating: pokemon_pix2pix_dataset/train/552.jpg
#   inflating: pokemon_pix2pix_dataset/train/553.jpg
#   inflating: pokemon_pix2pix_dataset/train/554.jpg
#   inflating: pokemon_pix2pix_dataset/train/555.jpg
#   inflating: pokemon_pix2pix_dataset/train/556.jpg
#   inflating: pokemon_pix2pix_dataset/train/557.jpg
#   inflating: pokemon_pix2pix_dataset/train/558.jpg
#   inflating: pokemon_pix2pix_dataset/train/559.jpg
#   inflating: pokemon_pix2pix_dataset/train/56.jpg
#   inflating: pokemon_pix2pix_dataset/train/560.jpg
#   inflating: pokemon_pix2pix_dataset/train/561.jpg
#   inflating: pokemon_pix2pix_dataset/train/562.jpg
#   inflating: pokemon_pix2pix_dataset/train/563.jpg
#   inflating: pokemon_pix2pix_dataset/train/564.jpg
#   inflating: pokemon_pix2pix_dataset/train/565.jpg
#   inflating: pokemon_pix2pix_dataset/train/566.jpg
#   inflating: pokemon_pix2pix_dataset/train/567.jpg
#   inflating: pokemon_pix2pix_dataset/train/568.jpg
#   inflating: pokemon_pix2pix_dataset/train/569.jpg
#   inflating: pokemon_pix2pix_dataset/train/57.jpg
#   inflating: pokemon_pix2pix_dataset/train/570.jpg
#   inflating: pokemon_pix2pix_dataset/train/571.jpg
#   inflating: pokemon_pix2pix_dataset/train/572.jpg
#   inflating: pokemon_pix2pix_dataset/train/573.jpg
#   inflating: pokemon_pix2pix_dataset/train/574.jpg
#   inflating: pokemon_pix2pix_dataset/train/575.jpg
#   inflating: pokemon_pix2pix_dataset/train/576.jpg
#   inflating: pokemon_pix2pix_dataset/train/577.jpg
#   inflating: pokemon_pix2pix_dataset/train/578.jpg
#   inflating: pokemon_pix2pix_dataset/train/579.jpg
#   inflating: pokemon_pix2pix_dataset/train/58.jpg
#   inflating: pokemon_pix2pix_dataset/train/580.jpg
#   inflating: pokemon_pix2pix_dataset/train/581.jpg
#   inflating: pokemon_pix2pix_dataset/train/582.jpg
#   inflating: pokemon_pix2pix_dataset/train/583.jpg
#   inflating: pokemon_pix2pix_dataset/train/584.jpg
#   inflating: pokemon_pix2pix_dataset/train/585.jpg
#   inflating: pokemon_pix2pix_dataset/train/586.jpg
#   inflating: pokemon_pix2pix_dataset/train/587.jpg
#   inflating: pokemon_pix2pix_dataset/train/588.jpg
#   inflating: pokemon_pix2pix_dataset/train/589.jpg
#   inflating: pokemon_pix2pix_dataset/train/59.jpg
#   inflating: pokemon_pix2pix_dataset/train/590.jpg
#   inflating: pokemon_pix2pix_dataset/train/591.jpg
#   inflating: pokemon_pix2pix_dataset/train/592.jpg
#   inflating: pokemon_pix2pix_dataset/train/593.jpg
#   inflating: pokemon_pix2pix_dataset/train/594.jpg
#   inflating: pokemon_pix2pix_dataset/train/595.jpg
#   inflating: pokemon_pix2pix_dataset/train/596.jpg
#   inflating: pokemon_pix2pix_dataset/train/597.jpg
#   inflating: pokemon_pix2pix_dataset/train/598.jpg
#   inflating: pokemon_pix2pix_dataset/train/599.jpg
#   inflating: pokemon_pix2pix_dataset/train/6.jpg
#   inflating: pokemon_pix2pix_dataset/train/60.jpg
#   inflating: pokemon_pix2pix_dataset/train/600.jpg
#   inflating: pokemon_pix2pix_dataset/train/790.jpg
#   inflating: pokemon_pix2pix_dataset/train/791.jpg
#   inflating: pokemon_pix2pix_dataset/train/792.jpg
#   inflating: pokemon_pix2pix_dataset/train/793.jpg
#   inflating: pokemon_pix2pix_dataset/train/794.jpg
#   inflating: pokemon_pix2pix_dataset/train/795.jpg
#   inflating: pokemon_pix2pix_dataset/train/796.jpg
#   inflating: pokemon_pix2pix_dataset/train/797.jpg
#   inflating: pokemon_pix2pix_dataset/train/798.jpg
#   inflating: pokemon_pix2pix_dataset/train/799.jpg
#   inflating: pokemon_pix2pix_dataset/train/8.jpg
#   inflating: pokemon_pix2pix_dataset/train/80.jpg
#   inflating: pokemon_pix2pix_dataset/train/800.jpg
#   inflating: pokemon_pix2pix_dataset/train/801.jpg
#   inflating: pokemon_pix2pix_dataset/train/802.jpg
#   inflating: pokemon_pix2pix_dataset/train/803.jpg
#   inflating: pokemon_pix2pix_dataset/train/804.jpg
#   inflating: pokemon_pix2pix_dataset/train/805.jpg
#   inflating: pokemon_pix2pix_dataset/train/806.jpg
#   inflating: pokemon_pix2pix_dataset/train/807.jpg
#   inflating: pokemon_pix2pix_dataset/train/808.jpg
#   inflating: pokemon_pix2pix_dataset/train/809.jpg
#   inflating: pokemon_pix2pix_dataset/train/81.jpg
#   inflating: pokemon_pix2pix_dataset/train/810.jpg
#   inflating: pokemon_pix2pix_dataset/train/811.jpg
#   inflating: pokemon_pix2pix_dataset/train/812.jpg
#   inflating: pokemon_pix2pix_dataset/train/813.jpg
#   inflating: pokemon_pix2pix_dataset/train/814.jpg
#   inflating: pokemon_pix2pix_dataset/train/815.jpg
#   inflating: pokemon_pix2pix_dataset/train/816.jpg
#   inflating: pokemon_pix2pix_dataset/train/817.jpg
#   inflating: pokemon_pix2pix_dataset/train/818.jpg
#   inflating: pokemon_pix2pix_dataset/train/819.jpg
#   inflating: pokemon_pix2pix_dataset/train/82.jpg
#   inflating: pokemon_pix2pix_dataset/train/820.jpg
#   inflating: pokemon_pix2pix_dataset/train/821.jpg
#   inflating: pokemon_pix2pix_dataset/train/822.jpg
#   inflating: pokemon_pix2pix_dataset/train/823.jpg
#   inflating: pokemon_pix2pix_dataset/train/824.jpg
#   inflating: pokemon_pix2pix_dataset/train/825.jpg
#   inflating: pokemon_pix2pix_dataset/train/826.jpg
#   inflating: pokemon_pix2pix_dataset/train/827.jpg
#   inflating: pokemon_pix2pix_dataset/train/828.jpg
#   inflating: pokemon_pix2pix_dataset/train/829.jpg
#   inflating: pokemon_pix2pix_dataset/train/83.jpg
#   inflating: pokemon_pix2pix_dataset/train/84.jpg
#   inflating: pokemon_pix2pix_dataset/train/85.jpg
#   inflating: pokemon_pix2pix_dataset/train/86.jpg
#   inflating: pokemon_pix2pix_dataset/train/87.jpg
#   inflating: pokemon_pix2pix_dataset/train/88.jpg
#   inflating: pokemon_pix2pix_dataset/train/89.jpg
#   inflating: pokemon_pix2pix_dataset/train/9.jpg
#   inflating: pokemon_pix2pix_dataset/train/90.jpg
#   inflating: pokemon_pix2pix_dataset/train/91.jpg
#   inflating: pokemon_pix2pix_dataset/train/92.jpg
#   inflating: pokemon_pix2pix_dataset/train/93.jpg
#   inflating: pokemon_pix2pix_dataset/train/94.jpg
#   inflating: pokemon_pix2pix_dataset/train/95.jpg
#   inflating: pokemon_pix2pix_dataset/train/96.jpg
#   inflating: pokemon_pix2pix_dataset/train/97.jpg
#   inflating: pokemon_pix2pix_dataset/train/98.jpg
#   inflating: pokemon_pix2pix_dataset/train/99.jpg

# %%
import os

data_path = 'data/pokemon_pix2pix_dataset/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 830

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

print("✅")
# Out:
# ✅

# %%
class Encoder(layers.Layer):
    def __init__(self):
        super(Encoder, self).__init__()
        filters = [64,128,256,512,512,512,512,512]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i == 0:
                self.blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.blocks.append(EncodeBlock(f))
    
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
    
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
Encoder().get_summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encode_block (EncodeBlock)   (None, 128, 128, 64)      3072
# _________________________________________________________________
# encode_block_1 (EncodeBlock) (None, 64, 64, 128)       131584
# _________________________________________________________________
# encode_block_2 (EncodeBlock) (None, 32, 32, 256)       525312
# _________________________________________________________________
# encode_block_3 (EncodeBlock) (None, 16, 16, 512)       2099200
# _________________________________________________________________
# encode_block_4 (EncodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# encode_block_5 (EncodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# encode_block_6 (EncodeBlock) (None, 2, 2, 512)         4196352
# _________________________________________________________________
# encode_block_7 (EncodeBlock) (None, 1, 1, 512)         4196352
# =================================================================
# Total params: 19,544,576
# Trainable params: 19,538,688
# Non-trainable params: 5,888
# _________________________________________________________________

# %%
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

    
class Decoder(layers.Layer):
    def __init__(self):
        super(Decoder, self).__init__()
        filters = [512,512,512,512,256,128,64]
        
        self.blocks = []
        for i, f in enumerate(filters):
            if i < 3:
                self.blocks.append(DecodeBlock(f))
            else:
                self.blocks.append(DecodeBlock(f, dropout=False))
                
        self.blocks.append(layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False))
        
    def call(self, x):
        for block in self.blocks:
            x = block(x)
        return x
            
    def get_summary(self, input_shape=(1,1,512)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        
print("✅")
# Out:
# ✅

# %%
Decoder().get_summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1, 1, 512)]       0
# _________________________________________________________________
# decode_block (DecodeBlock)   (None, 2, 2, 512)         4196352
# _________________________________________________________________
# decode_block_1 (DecodeBlock) (None, 4, 4, 512)         4196352
# _________________________________________________________________
# decode_block_2 (DecodeBlock) (None, 8, 8, 512)         4196352
# _________________________________________________________________
# decode_block_3 (DecodeBlock) (None, 16, 16, 512)       4196352
# _________________________________________________________________
# decode_block_4 (DecodeBlock) (None, 32, 32, 256)       2098176
# _________________________________________________________________
# decode_block_5 (DecodeBlock) (None, 64, 64, 128)       524800
# _________________________________________________________________
# decode_block_6 (DecodeBlock) (None, 128, 128, 64)      131328
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 256, 256, 3)       3072
# =================================================================
# Total params: 19,542,784
# Trainable params: 19,537,792
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
class EncoderDecoderGenerator(Model):
    def __init__(self):
        super(EncoderDecoderGenerator, self).__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()
    
    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
   
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()
        

EncoderDecoderGenerator().get_summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# encoder_1 (Encoder)          (None, 1, 1, 512)         19544576
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 256, 256, 3)       19542784
# =================================================================
# Total params: 39,087,360
# Trainable params: 39,076,480
# Non-trainable params: 10,880
# _________________________________________________________________

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_16 (EncodeBlock)   (None, 128, 128, 64) 3072        input_4[0][0]
# __________________________________________________________________________________________________
# encode_block_17 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_16[0][0]
# __________________________________________________________________________________________________
# encode_block_18 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_17[0][0]
# __________________________________________________________________________________________________
# encode_block_19 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_18[0][0]
# __________________________________________________________________________________________________
# encode_block_20 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_19[0][0]
# __________________________________________________________________________________________________
# encode_block_21 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_20[0][0]
# __________________________________________________________________________________________________
# encode_block_22 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_21[0][0]
# __________________________________________________________________________________________________
# encode_block_23 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_14 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_23[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block_14[0][0]
#                                                                  encode_block_22[0][0]
# __________________________________________________________________________________________________
# decode_block_15 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_15[0][0]
#                                                                  encode_block_21[0][0]
# __________________________________________________________________________________________________
# decode_block_16 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_16[0][0]
#                                                                  encode_block_20[0][0]
# __________________________________________________________________________________________________
# decode_block_17 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_17[0][0]
#                                                                  encode_block_19[0][0]
# __________________________________________________________________________________________________
# decode_block_18 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_18[0][0]
#                                                                  encode_block_18[0][0]
# __________________________________________________________________________________________________
# decode_block_19 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_19[0][0]
#                                                                  encode_block_17[0][0]
# __________________________________________________________________________________________________
# decode_block_20 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_20[0][0]
#                                                                  encode_block_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_6[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 10 #약 30분 정도 소요 됩니다.

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0602
# L1_loss:0.5720
# Discriminator_loss:1.0203
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.1185
# L1_loss:0.3775
# Discriminator_loss:0.9518
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.2642
# L1_loss:0.3207
# Discriminator_loss:1.0133
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.5659
# L1_loss:0.2610
# Discriminator_loss:0.9661
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.3903
# L1_loss:0.2915
# Discriminator_loss:0.8787
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.4962
# L1_loss:0.3173
# Discriminator_loss:1.0033
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.7525
# L1_loss:0.3437
# Discriminator_loss:0.5375
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.8657
# L1_loss:0.2670
# Discriminator_loss:0.4224
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.7071
# L1_loss:0.2648
# Discriminator_loss:0.3439
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.8850
# L1_loss:0.2667
# Discriminator_loss:0.3699
#
# EPOCH[1] - STEP[110]
# Generator_loss:2.3425
# L1_loss:0.2253
# Discriminator_loss:0.6722
#
# EPOCH[1] - STEP[120]
# Generator_loss:2.5913
# L1_loss:0.3273
# Discriminator_loss:0.2639
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.9966
# L1_loss:0.2422
# Discriminator_loss:2.3983
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.2355
# L1_loss:0.2402
# Discriminator_loss:0.3191
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.6956
# L1_loss:0.3803
# Discriminator_loss:0.1730
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.8295
# L1_loss:0.2437
# Discriminator_loss:0.6585
#
# EPOCH[1] - STEP[170]
# Generator_loss:2.8553
# L1_loss:0.2490
# Discriminator_loss:0.8872
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.9272
# L1_loss:0.2356
# Discriminator_loss:0.3046
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.5039
# L1_loss:0.2309
# Discriminator_loss:0.4128
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.8382
# L1_loss:0.3290
# Discriminator_loss:0.3292
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.0547
# L1_loss:0.2621
# Discriminator_loss:0.4004
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.8356
# L1_loss:0.2807
# Discriminator_loss:0.1704
#
# EPOCH[2] - STEP[30]
# Generator_loss:0.5877
# L1_loss:0.2575
# Discriminator_loss:1.0507
#
# EPOCH[2] - STEP[40]
# Generator_loss:2.8884
# L1_loss:0.2519
# Discriminator_loss:0.5284
#
# EPOCH[2] - STEP[50]
# Generator_loss:0.6950
# L1_loss:0.2825
# Discriminator_loss:0.8916
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.2179
# L1_loss:0.2139
# Discriminator_loss:0.2216
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.6504
# L1_loss:0.2871
# Discriminator_loss:0.3358
#
# EPOCH[2] - STEP[80]
# Generator_loss:2.1694
# L1_loss:0.2279
# Discriminator_loss:0.2566
#
# EPOCH[2] - STEP[90]
# Generator_loss:0.7224
# L1_loss:0.2391
# Discriminator_loss:0.7906
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.5345
# L1_loss:0.2499
# Discriminator_loss:1.1599
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.4750
# L1_loss:0.2166
# Discriminator_loss:0.5277
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.1618
# L1_loss:0.2892
# Discriminator_loss:0.2344
#
# EPOCH[2] - STEP[130]
# Generator_loss:2.5909
# L1_loss:0.2854
# Discriminator_loss:0.3673
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.2418
# L1_loss:0.2475
# Discriminator_loss:0.4574
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.9818
# L1_loss:0.2537
# Discriminator_loss:0.4008
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.9122
# L1_loss:0.2535
# Discriminator_loss:0.5801
#
# EPOCH[2] - STEP[170]
# Generator_loss:2.3164
# L1_loss:0.3048
# Discriminator_loss:0.2517
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.9337
# L1_loss:0.2651
# Discriminator_loss:0.4774
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.9424
# L1_loss:0.2110
# Discriminator_loss:0.5652
#
# EPOCH[2] - STEP[200]
# Generator_loss:3.0154
# L1_loss:0.2622
# Discriminator_loss:0.1963
#
# EPOCH[3] - STEP[10]
# Generator_loss:3.6704
# L1_loss:0.2830
# Discriminator_loss:0.4432
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.6195
# L1_loss:0.2203
# Discriminator_loss:0.9775
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.9019
# L1_loss:0.2509
# Discriminator_loss:0.3130
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.7346
# L1_loss:0.2584
# Discriminator_loss:0.4591
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.8442
# L1_loss:0.2863
# Discriminator_loss:0.2858
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.0827
# L1_loss:0.2099
# Discriminator_loss:0.4779
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.2721
# L1_loss:0.2250
# Discriminator_loss:0.5843
#
# EPOCH[3] - STEP[80]
# Generator_loss:3.4684
# L1_loss:0.2208
# Discriminator_loss:0.3661
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.0047
# L1_loss:0.2701
# Discriminator_loss:0.6082
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.6199
# L1_loss:0.2248
# Discriminator_loss:0.7070
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.8646
# L1_loss:0.2597
# Discriminator_loss:0.1874
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.4148
# L1_loss:0.3841
# Discriminator_loss:0.3908
#
# EPOCH[3] - STEP[130]
# Generator_loss:2.3520
# L1_loss:0.2653
# Discriminator_loss:0.3646
#
# EPOCH[3] - STEP[140]
# Generator_loss:1.6773
# L1_loss:0.2885
# Discriminator_loss:0.2401
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.4022
# L1_loss:0.2565
# Discriminator_loss:0.5691
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.0454
# L1_loss:0.3149
# Discriminator_loss:0.2449
# EPOCH[3] - STEP[170]
# Generator_loss:1.6307
# L1_loss:0.2411
# Discriminator_loss:0.4641
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.8662
# L1_loss:0.3189
# Discriminator_loss:0.2622
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.8761
# L1_loss:0.2615
# Discriminator_loss:0.3247
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.0346
# L1_loss:0.2687
# Discriminator_loss:0.3641
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.0605
# L1_loss:0.2107
# Discriminator_loss:1.2757
#
# EPOCH[4] - STEP[20]
# Generator_loss:1.3742
# L1_loss:0.2205
# Discriminator_loss:1.2386
#
# EPOCH[4] - STEP[30]
# Generator_loss:0.9996
# L1_loss:0.2403
# Discriminator_loss:0.5732
#
# EPOCH[4] - STEP[40]
# Generator_loss:0.2619
# L1_loss:0.2514
# Discriminator_loss:1.7155
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.6126
# L1_loss:0.2847
# Discriminator_loss:0.6894
#
# EPOCH[4] - STEP[60]
# Generator_loss:2.0012
# L1_loss:0.2901
# Discriminator_loss:0.2554
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.4792
# L1_loss:0.2449
# Discriminator_loss:0.1984
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.9096
# L1_loss:0.2809
# Discriminator_loss:0.3468
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.3716
# L1_loss:0.2307
# Discriminator_loss:1.3872
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.4244
# L1_loss:0.2112
# Discriminator_loss:0.6143
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.5635
# L1_loss:0.2131
# Discriminator_loss:0.7211
#
# EPOCH[4] - STEP[120]
# Generator_loss:0.1240
# L1_loss:0.2784
# Discriminator_loss:2.4700
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.6510
# L1_loss:0.2707
# Discriminator_loss:0.3416
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.1034
# L1_loss:0.2962
# Discriminator_loss:1.8160
#
# EPOCH[4] - STEP[150]
# Generator_loss:2.6393
# L1_loss:0.2697
# Discriminator_loss:0.8757
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.5961
# L1_loss:0.2351
# Discriminator_loss:0.3368
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.3878
# L1_loss:0.2396
# Discriminator_loss:0.5647
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.5749
# L1_loss:0.2569
# Discriminator_loss:0.9901
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.4340
# L1_loss:0.2769
# Discriminator_loss:0.2620
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.5245
# L1_loss:0.2668
# Discriminator_loss:0.5894
#
# EPOCH[5] - STEP[10]
# Generator_loss:0.7038
# L1_loss:0.2136
# Discriminator_loss:0.8730
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.8612
# L1_loss:0.2628
# Discriminator_loss:0.7184
#
# EPOCH[5] - STEP[30]
# Generator_loss:3.0096
# L1_loss:0.2352
# Discriminator_loss:0.8462
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.8966
# L1_loss:0.2590
# Discriminator_loss:0.2370
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.2605
# L1_loss:0.3160
# Discriminator_loss:1.7712
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.8300
# L1_loss:0.2089
# Discriminator_loss:0.8182
#
# EPOCH[5] - STEP[70]
# Generator_loss:1.4903
# L1_loss:0.2683
# Discriminator_loss:0.4570
#
# EPOCH[5] - STEP[80]
# Generator_loss:0.4269
# L1_loss:0.2048
# Discriminator_loss:1.2209
#
# EPOCH[5] - STEP[90]
# Generator_loss:0.4064
# L1_loss:0.2480
# Discriminator_loss:1.2238
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.2748
# L1_loss:0.2276
# Discriminator_loss:0.6657
#
# EPOCH[5] - STEP[110]
# Generator_loss:0.6062
# L1_loss:0.3076
# Discriminator_loss:0.9355
#
# EPOCH[5] - STEP[120]
# Generator_loss:0.6985
# L1_loss:0.3056
# Discriminator_loss:0.7596
#
# EPOCH[5] - STEP[130]
# Generator_loss:3.2548
# L1_loss:0.2549
# Discriminator_loss:0.8042
#
# EPOCH[5] - STEP[140]
# Generator_loss:1.8329
# L1_loss:0.2582
# Discriminator_loss:0.2317
#
# EPOCH[5] - STEP[150]
# Generator_loss:2.2043
# L1_loss:0.2369
# Discriminator_loss:0.5360
#
# EPOCH[5] - STEP[160]
# Generator_loss:0.6042
# L1_loss:0.2212
# Discriminator_loss:1.1648
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.2029
# L1_loss:0.2306
# Discriminator_loss:0.1859
#
# EPOCH[5] - STEP[180]
# Generator_loss:0.9440
# L1_loss:0.2508
# Discriminator_loss:1.1213
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.5989
# L1_loss:0.2497
# Discriminator_loss:0.5305
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.8428
# L1_loss:0.3262
# Discriminator_loss:0.5045
#
# EPOCH[6] - STEP[10]
# Generator_loss:1.7521
# L1_loss:0.2330
# Discriminator_loss:0.3399
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.4893
# L1_loss:0.2413
# Discriminator_loss:0.8658
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.6449
# L1_loss:0.2254
# Discriminator_loss:0.4584
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.5231
# L1_loss:0.3307
# Discriminator_loss:1.1313
#
# EPOCH[6] - STEP[50]
# Generator_loss:1.3334
# L1_loss:0.2449
# Discriminator_loss:0.4380
#
# EPOCH[6] - STEP[60]
# Generator_loss:0.7055
# L1_loss:0.3091
# Discriminator_loss:0.9020
#
# EPOCH[6] - STEP[70]
# Generator_loss:0.2269
# L1_loss:0.2509
# Discriminator_loss:2.0407
#
# EPOCH[6] - STEP[80]
# Generator_loss:0.9548
# L1_loss:0.2689
# Discriminator_loss:0.5874
#
# EPOCH[6] - STEP[90]
# Generator_loss:0.7887
# L1_loss:0.2804
# Discriminator_loss:0.9676
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.7527
# L1_loss:0.2789
# Discriminator_loss:0.3715
#
# EPOCH[6] - STEP[110]
# Generator_loss:2.8406
# L1_loss:0.3021
# Discriminator_loss:0.5349
#
# EPOCH[6] - STEP[120]
# Generator_loss:1.6166
# L1_loss:0.2586
# Discriminator_loss:0.5855
# EPOCH[6] - STEP[130]
# Generator_loss:0.4518
# L1_loss:0.2262
# Discriminator_loss:1.4475
#
# EPOCH[6] - STEP[140]
# Generator_loss:3.0457
# L1_loss:0.2274
# Discriminator_loss:0.6442
#
# EPOCH[6] - STEP[150]
# Generator_loss:1.5553
# L1_loss:0.2646
# Discriminator_loss:0.3392
#
# EPOCH[6] - STEP[160]
# Generator_loss:2.2705
# L1_loss:0.2539
# Discriminator_loss:0.5731
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.0384
# L1_loss:0.2718
# Discriminator_loss:1.5700
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.1503
# L1_loss:0.2212
# Discriminator_loss:0.8227
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.8466
# L1_loss:0.2502
# Discriminator_loss:0.8358
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.1897
# L1_loss:0.2509
# Discriminator_loss:1.9288
#
# EPOCH[7] - STEP[10]
# Generator_loss:2.6368
# L1_loss:0.2337
# Discriminator_loss:0.3202
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.0754
# L1_loss:0.2319
# Discriminator_loss:0.5984
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.7288
# L1_loss:0.2428
# Discriminator_loss:0.9188
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.7567
# L1_loss:0.2207
# Discriminator_loss:1.6682
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.1730
# L1_loss:0.2189
# Discriminator_loss:1.1074
#
# EPOCH[7] - STEP[60]
# Generator_loss:4.3308
# L1_loss:0.2927
# Discriminator_loss:0.8756
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.9855
# L1_loss:0.2426
# Discriminator_loss:0.6228
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.8857
# L1_loss:0.2567
# Discriminator_loss:0.9841
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.3533
# L1_loss:0.2510
# Discriminator_loss:1.4125
#
# EPOCH[7] - STEP[100]
# Generator_loss:3.0305
# L1_loss:0.2772
# Discriminator_loss:0.2229
#
# EPOCH[7] - STEP[110]
# Generator_loss:4.3373
# L1_loss:0.3015
# Discriminator_loss:0.5046
#
# EPOCH[7] - STEP[120]
# Generator_loss:0.4358
# L1_loss:0.2197
# Discriminator_loss:1.2835
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.1224
# L1_loss:0.2772
# Discriminator_loss:0.1684
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.9574
# L1_loss:0.2671
# Discriminator_loss:0.5080
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.0479
# L1_loss:0.2607
# Discriminator_loss:1.5501
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.3517
# L1_loss:0.2479
# Discriminator_loss:0.4977
#
# EPOCH[7] - STEP[170]
# Generator_loss:1.7069
# L1_loss:0.2530
# Discriminator_loss:0.4263
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.1676
# L1_loss:0.2479
# Discriminator_loss:0.9658
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.6653
# L1_loss:0.2498
# Discriminator_loss:0.6054
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.5335
# L1_loss:0.1959
# Discriminator_loss:1.3449
#
# EPOCH[8] - STEP[10]
# Generator_loss:1.8319
# L1_loss:0.2738
# Discriminator_loss:0.7208
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.7356
# L1_loss:0.2604
# Discriminator_loss:0.2565
#
# EPOCH[8] - STEP[30]
# Generator_loss:2.4464
# L1_loss:0.2517
# Discriminator_loss:0.7714
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.4069
# L1_loss:0.2456
# Discriminator_loss:1.3386
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.7908
# L1_loss:0.2307
# Discriminator_loss:0.6955
#
# EPOCH[8] - STEP[60]
# Generator_loss:0.5530
# L1_loss:0.2182
# Discriminator_loss:1.0268
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.4735
# L1_loss:0.2834
# Discriminator_loss:0.1439
#
# EPOCH[8] - STEP[80]
# Generator_loss:2.4412
# L1_loss:0.2294
# Discriminator_loss:0.4219
#
# EPOCH[8] - STEP[90]
# Generator_loss:1.5518
# L1_loss:0.2944
# Discriminator_loss:0.5092
#
# EPOCH[8] - STEP[100]
# Generator_loss:4.0413
# L1_loss:0.2914
# Discriminator_loss:0.1126
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.6667
# L1_loss:0.2079
# Discriminator_loss:1.0725
#
# EPOCH[8] - STEP[120]
# Generator_loss:0.2492
# L1_loss:0.2045
# Discriminator_loss:2.3042
#
# EPOCH[8] - STEP[130]
# Generator_loss:2.1859
# L1_loss:0.2332
# Discriminator_loss:0.4382
#
# EPOCH[8] - STEP[140]
# Generator_loss:2.6694
# L1_loss:0.2527
# Discriminator_loss:1.0920
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.9210
# L1_loss:0.2686
# Discriminator_loss:0.6934
#
# EPOCH[8] - STEP[160]
# Generator_loss:3.3161
# L1_loss:0.2645
# Discriminator_loss:0.3764
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.8196
# L1_loss:0.2824
# Discriminator_loss:0.0967
#
# EPOCH[8] - STEP[180]
# Generator_loss:1.8765
# L1_loss:0.2879
# Discriminator_loss:0.6256
#
# EPOCH[8] - STEP[190]
# Generator_loss:2.3100
# L1_loss:0.2531
# Discriminator_loss:0.2996
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.7088
# L1_loss:0.2528
# Discriminator_loss:0.9135
#
# EPOCH[9] - STEP[10]
# Generator_loss:2.6887
# L1_loss:0.2333
# Discriminator_loss:0.3585
#
# EPOCH[9] - STEP[20]
# Generator_loss:2.7774
# L1_loss:0.2206
# Discriminator_loss:0.9984
#
# EPOCH[9] - STEP[30]
# Generator_loss:2.9744
# L1_loss:0.2294
# Discriminator_loss:1.0189
#
# EPOCH[9] - STEP[40]
# Generator_loss:3.0379
# L1_loss:0.2975
# Discriminator_loss:0.1049
#
# EPOCH[9] - STEP[50]
# Generator_loss:0.4366
# L1_loss:0.2315
# Discriminator_loss:1.3518
#
# EPOCH[9] - STEP[60]
# Generator_loss:3.1999
# L1_loss:0.2260
# Discriminator_loss:1.0235
#
# EPOCH[9] - STEP[70]
# Generator_loss:3.5177
# L1_loss:0.2335
# Discriminator_loss:0.7918
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.7495
# L1_loss:0.2907
# Discriminator_loss:0.5954
# EPOCH[9] - STEP[90]
# Generator_loss:2.8582
# L1_loss:0.2493
# Discriminator_loss:1.3820
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.2332
# L1_loss:0.2213
# Discriminator_loss:1.3456
#
# EPOCH[9] - STEP[110]
# Generator_loss:2.1782
# L1_loss:0.2539
# Discriminator_loss:1.7180
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.6968
# L1_loss:0.2493
# Discriminator_loss:0.3182
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.7286
# L1_loss:0.2733
# Discriminator_loss:0.8166
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.6170
# L1_loss:0.3071
# Discriminator_loss:0.3804
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.2019
# L1_loss:0.2393
# Discriminator_loss:0.5470
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.9049
# L1_loss:0.2290
# Discriminator_loss:0.4196
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.7632
# L1_loss:0.2223
# Discriminator_loss:0.5708
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.6958
# L1_loss:0.2514
# Discriminator_loss:0.5251
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.1167
# L1_loss:0.2147
# Discriminator_loss:1.2973
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.5297
# L1_loss:0.2736
# Discriminator_loss:1.0186
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.7963
# L1_loss:0.2253
# Discriminator_loss:0.7251
#
# EPOCH[10] - STEP[20]
# Generator_loss:0.5842
# L1_loss:0.2461
# Discriminator_loss:1.2548
#
# EPOCH[10] - STEP[30]
# Generator_loss:2.2374
# L1_loss:0.2600
# Discriminator_loss:1.9605
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.7284
# L1_loss:0.3303
# Discriminator_loss:0.3720
#
# EPOCH[10] - STEP[50]
# Generator_loss:2.0000
# L1_loss:0.2601
# Discriminator_loss:0.4037
#
# EPOCH[10] - STEP[60]
# Generator_loss:2.3760
# L1_loss:0.2916
# Discriminator_loss:0.5000
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.0168
# L1_loss:0.2000
# Discriminator_loss:1.4732
#
# EPOCH[10] - STEP[80]
# Generator_loss:1.9207
# L1_loss:0.2991
# Discriminator_loss:0.3821
#
# EPOCH[10] - STEP[90]
# Generator_loss:2.5839
# L1_loss:0.2353
# Discriminator_loss:0.4774
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.3245
# L1_loss:0.2604
# Discriminator_loss:1.3919
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.8208
# L1_loss:0.2925
# Discriminator_loss:0.2434
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.9922
# L1_loss:0.2287
# Discriminator_loss:0.6767
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.5601
# L1_loss:0.2093
# Discriminator_loss:0.4931
#
# EPOCH[10] - STEP[140]
# Generator_loss:3.1244
# L1_loss:0.2934
# Discriminator_loss:0.5105
#
# EPOCH[10] - STEP[150]
# Generator_loss:0.1748
# L1_loss:0.1833
# Discriminator_loss:2.0531
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.2947
# L1_loss:0.3046
# Discriminator_loss:0.1473
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.6162
# L1_loss:0.2393
# Discriminator_loss:1.3384
#
# EPOCH[10] - STEP[180]
# Generator_loss:3.0213
# L1_loss:0.2403
# Discriminator_loss:0.3819
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.6704
# L1_loss:0.2500
# Discriminator_loss:0.3228
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.6771
# L1_loss:0.2939
# Discriminator_loss:0.2948

# %%
test_ind = 0

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
